# %%
# %load_ext autoreload
# %autoreload 2
import torch
import copy
import os

import torch
import tqdm
import torchvision

from typing import Literal

import abstract_gradient_training as agt
from abstract_gradient_training import AGTConfig
from abstract_gradient_training.bounded_models import IntervalBoundedModel

import uci_datasets  # python -m pip install git+https://github.com/treforevans/uci_datasets.git
torch.manual_seed(0)

# %%
batchsize = 1000000
data = uci_datasets.Dataset("houseelectric")
print(data)
x_train, y_train, x_test, y_test = data.get_split(split=0)

# Normalise the features and labels
x_train_mu, x_train_std = x_train.mean(axis=0), x_train.std(axis=0)
x_train = (x_train - x_train_mu) / x_train_std
x_test = (x_test - x_train_mu) / x_train_std
y_train_min, y_train_range = y_train.min(axis=0), y_train.max(axis=0) - y_train.min(axis=0)
y_train = (y_train - y_train_min) / y_train_range
y_test = (y_test - y_train_min) / y_train_range

# Form datasets and dataloaders
train_data = torch.utils.data.TensorDataset(torch.from_numpy(x_train).float(), torch.from_numpy(y_train).float())
test_data = torch.utils.data.TensorDataset(torch.from_numpy(x_test).float(), torch.from_numpy(y_test).float())
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batchsize, shuffle=False)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=1000, shuffle=False)
# Out:
# houseelectric dataset, N=2049280, d=11
# <uci_datasets.dataset.Dataset object at 0x719b1cb63670>

# %%
# batchsize = 1000000
# # configure the training parameters
# nominal_config = agt.AGTConfig(
#     fragsize=20000,
#     learning_rate=0.005,
#     epsilon=0.01,
#     k_private=1,
#     n_epochs=1,
#     device="cuda:0",
#     loss="mse",
#     log_level="DEBUG",
#     optimizer="SGDM", # we'll use SGD with momentum
#     optimizer_kwargs={"momentum": 0.9, "nesterov": True},
# )

# set up the AGT configuration
nominal_config = AGTConfig(
    fragsize=2000,
    learning_rate=0.25,
    n_epochs=10,
    device="cuda:1",
    l2_reg=0.01,
    k_private=1,
    loss="mse",
    log_level="INFO",
    lr_decay=2.0,
    clip_gamma=1.0,
    lr_min=0.001,
    optimizer="SGDM", # we'll use SGD with momentum
    optimizer_kwargs={"momentum": 0.9, "nesterov": True},
)

# %%
# to use privacy-safe certificates, we need to run AGT for a range of k_private values

# we'll just pick a reasonable range of k_private values. adding more values will increase the runtime
# but also result in tighter privacy results. even a few values are sufficient to demonstrate tighter privacy

k_private_values = [1, 2, 5, 10, 20, 50, 100] 
privacy_bounded_models = {}
config = copy.deepcopy(nominal_config)
# config.log_level = "WARNING"

for k_private in tqdm.tqdm(k_private_values):
    # update config
    config.k_private = k_private
    # form bounded model
    torch.manual_seed(1)
    # get the nn model
    model = torch.nn.Sequential(torch.nn.Linear(11, 128), torch.nn.ReLU(), torch.nn.Linear(128, 1)).to(config.device)
    bounded_model = IntervalBoundedModel(model, trainable=True)
    # dl_train = torch.utils.data.DataLoader(dataset_train, batch_size=batchsize, shuffle=True)
    # run AGT
    agt.privacy_certified_training(bounded_model, config, train_loader, dl_val=test_loader)
    privacy_bounded_models[k_private] = bounded_model
    path = os.getcwd()
    privacy_bounded_models[k_private].save_params(f"{path}/models/32/uci_k_{k_private}.model")
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# [AGT] [INFO    ] [20:44:02] =================== Starting Privacy Certified Training ===================
# [AGT] [INFO    ] [20:44:02] Starting epoch 1
# [AGT] [INFO    ] [20:44:13] Batch 1. Loss (mse): 0.346 <= 0.346 <= 0.346
# [AGT] [ERROR   ] [20:44:31] Violated bound in validate_interval: 7.99e-02 (grad bounds, private fragment (element 0))
# [AGT] [ERROR   ] [20:44:31] Violated bound in validate_interval: 4.60e-02 (grad bounds, private fragment (element 1))
# [AGT] [INFO    ] [20:45:30] Starting epoch 2
# [AGT] [INFO    ] [20:45:39] Batch 2. Loss (mse): 0.686 <= 0.686 <= 0.686
# [AGT] [INFO    ] [20:46:55] Starting epoch 3
# [AGT] [INFO    ] [20:47:04] Batch 3. Loss (mse): 0.233 <= 0.233 <= 0.233
# [AGT] [INFO    ] [20:48:21] Starting epoch 4
# [AGT] [INFO    ] [20:48:30] Batch 4. Loss (mse): 0.082 <= 0.083 <= 0.083
# [AGT] [INFO    ] [20:49:43] Starting epoch 5
# [AGT] [INFO    ] [20:49:52] Batch 5. Loss (mse): 0.040 <= 0.040 <= 0.040
# [AGT] [INFO    ] [20:51:09] Starting epoch 6
# [AGT] [INFO    ] [20:51:19] Batch 6. Loss (mse): 0.037 <= 0.038 <= 0.038
# [AGT] [INFO    ] [20:52:35] Starting epoch 7
# [AGT] [INFO    ] [20:52:44] Batch 7. Loss (mse): 0.047 <= 0.047 <= 0.047
# [AGT] [INFO    ] [20:53:58] Starting epoch 8
# [AGT] [INFO    ] [20:54:07] Batch 8. Loss (mse): 0.040 <= 0.040 <= 0.041
# [AGT] [INFO    ] [20:55:24] Starting epoch 9
# [AGT] [INFO    ] [20:55:33] Batch 9. Loss (mse): 0.042 <= 0.042 <= 0.043
# [AGT] [INFO    ] [20:56:47] Starting epoch 10
# [AGT] [INFO    ] [20:56:56] Batch 10. Loss (mse): 0.036 <= 0.037 <= 0.037
# [AGT] [INFO    ] [20:58:20] Final Eval. Loss (mse): 0.038 <= 0.038 <= 0.039
# [AGT] [INFO    ] [20:58:20] =================== Finished Privacy Certified Training ===================
#  14%|█▍        | 1/7 [14:18<1:25:51, 858.57s/it][AGT] [INFO    ] [20:58:20] =================== Starting Privacy Certified Training ===================
# [AGT] [INFO    ] [20:58:20] Starting epoch 1
# [AGT] [INFO    ] [20:58:29] Batch 1. Loss (mse): 0.346 <= 0.346 <= 0.346
# [AGT] [ERROR   ] [20:58:51] Violated bound in validate_interval: 7.99e-02 (grad bounds, private fragment (element 0))
# [AGT] [ERROR   ] [20:58:51] Violated bound in validate_interval: 4.60e-02 (grad bounds, private fragment (element 1))
# [AGT] [INFO    ] [20:59:56] Starting epoch 2
# [AGT] [INFO    ] [21:00:05] Batch 2. Loss (mse): 0.686 <= 0.686 <= 0.686
# [AGT] [INFO    ] [21:01:32] Starting epoch 3
# [AGT] [INFO    ] [21:01:41] Batch 3. Loss (mse): 0.233 <= 0.233 <= 0.233
# [AGT] [INFO    ] [21:03:04] Starting epoch 4
# [AGT] [INFO    ] [21:03:13] Batch 4. Loss (mse): 0.082 <= 0.083 <= 0.083
# [AGT] [INFO    ] [21:04:39] Starting epoch 5
# [AGT] [INFO    ] [21:04:48] Batch 5. Loss (mse): 0.040 <= 0.040 <= 0.040
# [AGT] [INFO    ] [21:06:22] Starting epoch 6
# [AGT] [INFO    ] [21:06:31] Batch 6. Loss (mse): 0.037 <= 0.038 <= 0.038
# [AGT] [INFO    ] [21:08:06] Starting epoch 7
# [AGT] [INFO    ] [21:08:15] Batch 7. Loss (mse): 0.047 <= 0.047 <= 0.047
# [AGT] [INFO    ] [21:09:49] Starting epoch 8
# [AGT] [INFO    ] [21:09:59] Batch 8. Loss (mse): 0.040 <= 0.040 <= 0.041
# [AGT] [INFO    ] [21:11:33] Starting epoch 9
# [AGT] [INFO    ] [21:11:42] Batch 9. Loss (mse): 0.042 <= 0.042 <= 0.043
# [AGT] [INFO    ] [21:13:16] Starting epoch 10
# [AGT] [INFO    ] [21:13:25] Batch 10. Loss (mse): 0.036 <= 0.037 <= 0.037
# [AGT] [INFO    ] [21:15:01] Final Eval. Loss (mse): 0.038 <= 0.038 <= 0.039
# [AGT] [INFO    ] [21:15:01] =================== Finished Privacy Certified Training ===================
#  29%|██▊       | 2/7 [30:59<1:18:30, 942.20s/it][AGT] [INFO    ] [21:15:01] =================== Starting Privacy Certified Training ===================
# [AGT] [INFO    ] [21:15:01] Starting epoch 1
# [AGT] [INFO    ] [21:15:10] Batch 1. Loss (mse): 0.346 <= 0.346 <= 0.346
# [AGT] [ERROR   ] [21:15:34] Violated bound in validate_interval: 7.99e-02 (grad bounds, private fragment (element 0))
# [AGT] [ERROR   ] [21:15:34] Violated bound in validate_interval: 4.60e-02 (grad bounds, private fragment (element 1))
# [AGT] [INFO    ] [21:16:46] Starting epoch 2
# [AGT] [INFO    ] [21:16:55] Batch 2. Loss (mse): 0.685 <= 0.686 <= 0.686
# [AGT] [INFO    ] [21:18:20] Starting epoch 3
# [AGT] [INFO    ] [21:18:29] Batch 3. Loss (mse): 0.233 <= 0.233 <= 0.233
# [AGT] [INFO    ] [21:19:53] Starting epoch 4
# [AGT] [INFO    ] [21:20:02] Batch 4. Loss (mse): 0.082 <= 0.083 <= 0.083
# [AGT] [INFO    ] [21:21:19] Starting epoch 5
# [AGT] [INFO    ] [21:21:28] Batch 5. Loss (mse): 0.040 <= 0.040 <= 0.040
# [AGT] [INFO    ] [21:22:45] Starting epoch 6
# [AGT] [INFO    ] [21:22:54] Batch 6. Loss (mse): 0.037 <= 0.038 <= 0.038
# [AGT] [INFO    ] [21:24:08] Starting epoch 7
# [AGT] [INFO    ] [21:24:17] Batch 7. Loss (mse): 0.046 <= 0.047 <= 0.047
# [AGT] [INFO    ] [21:25:34] Starting epoch 8
# [AGT] [INFO    ] [21:25:43] Batch 8. Loss (mse): 0.040 <= 0.040 <= 0.041
# [AGT] [INFO    ] [21:26:59] Starting epoch 9
# [AGT] [INFO    ] [21:27:08] Batch 9. Loss (mse): 0.041 <= 0.042 <= 0.043
# [AGT] [INFO    ] [21:28:23] Starting epoch 10
# [AGT] [INFO    ] [21:28:32] Batch 10. Loss (mse): 0.035 <= 0.037 <= 0.038
# [AGT] [INFO    ] [21:29:56] Final Eval. Loss (mse): 0.037 <= 0.038 <= 0.040
# [AGT] [INFO    ] [21:29:56] =================== Finished Privacy Certified Training ===================
#  43%|████▎     | 3/7 [45:54<1:01:22, 920.55s/it][AGT] [INFO    ] [21:29:56] =================== Starting Privacy Certified Training ===================
# [AGT] [INFO    ] [21:29:56] Starting epoch 1
# [AGT] [INFO    ] [21:30:05] Batch 1. Loss (mse): 0.346 <= 0.346 <= 0.346
# [AGT] [ERROR   ] [21:30:26] Violated bound in validate_interval: 7.99e-02 (grad bounds, private fragment (element 0))
# [AGT] [ERROR   ] [21:30:26] Violated bound in validate_interval: 4.60e-02 (grad bounds, private fragment (element 1))
# [AGT] [INFO    ] [21:31:22] Starting epoch 2
# [AGT] [INFO    ] [21:31:31] Batch 2. Loss (mse): 0.685 <= 0.686 <= 0.686
# [AGT] [INFO    ] [21:32:45] Starting epoch 3
# [AGT] [INFO    ] [21:32:54] Batch 3. Loss (mse): 0.232 <= 0.233 <= 0.233
# [AGT] [INFO    ] [21:34:13] Starting epoch 4
# [AGT] [INFO    ] [21:34:22] Batch 4. Loss (mse): 0.082 <= 0.083 <= 0.083
# [AGT] [INFO    ] [21:35:39] Starting epoch 5
# [AGT] [INFO    ] [21:35:48] Batch 5. Loss (mse): 0.039 <= 0.040 <= 0.040
# [AGT] [INFO    ] [21:37:04] Starting epoch 6
# [AGT] [INFO    ] [21:37:14] Batch 6. Loss (mse): 0.037 <= 0.038 <= 0.038
# [AGT] [INFO    ] [21:38:31] Starting epoch 7
# [AGT] [INFO    ] [21:38:40] Batch 7. Loss (mse): 0.046 <= 0.047 <= 0.048
# [AGT] [INFO    ] [21:39:58] Starting epoch 8
# [AGT] [INFO    ] [21:40:07] Batch 8. Loss (mse): 0.039 <= 0.040 <= 0.042
# [AGT] [INFO    ] [21:41:26] Starting epoch 9
# [AGT] [INFO    ] [21:41:35] Batch 9. Loss (mse): 0.040 <= 0.042 <= 0.045
# [AGT] [INFO    ] [21:42:57] Starting epoch 10
# [AGT] [INFO    ] [21:43:06] Batch 10. Loss (mse): 0.034 <= 0.037 <= 0.039
# [AGT] [INFO    ] [21:44:19] Final Eval. Loss (mse): 0.035 <= 0.038 <= 0.042
# [AGT] [INFO    ] [21:44:19] =================== Finished Privacy Certified Training ===================
#  57%|█████▋    | 4/7 [1:00:17<44:54, 898.06s/it][AGT] [INFO    ] [21:44:19] =================== Starting Privacy Certified Training ===================
# [AGT] [INFO    ] [21:44:19] Starting epoch 1
# [AGT] [INFO    ] [21:44:28] Batch 1. Loss (mse): 0.346 <= 0.346 <= 0.346
# [AGT] [ERROR   ] [21:44:47] Violated bound in validate_interval: 7.99e-02 (grad bounds, private fragment (element 0))
# [AGT] [ERROR   ] [21:44:47] Violated bound in validate_interval: 4.60e-02 (grad bounds, private fragment (element 1))
# [AGT] [INFO    ] [21:45:46] Starting epoch 2
# [AGT] [INFO    ] [21:45:55] Batch 2. Loss (mse): 0.685 <= 0.686 <= 0.686
# [AGT] [INFO    ] [21:47:12] Starting epoch 3
# [AGT] [INFO    ] [21:47:21] Batch 3. Loss (mse): 0.232 <= 0.233 <= 0.234
# [AGT] [INFO    ] [21:48:38] Starting epoch 4
# [AGT] [INFO    ] [21:48:47] Batch 4. Loss (mse): 0.082 <= 0.083 <= 0.083
# [AGT] [INFO    ] [21:50:04] Starting epoch 5
# [AGT] [INFO    ] [21:50:13] Batch 5. Loss (mse): 0.039 <= 0.040 <= 0.041
# [AGT] [INFO    ] [21:51:44] Starting epoch 6
# [AGT] [INFO    ] [21:51:53] Batch 6. Loss (mse): 0.036 <= 0.038 <= 0.039
# [AGT] [INFO    ] [21:53:32] Starting epoch 7
# [AGT] [INFO    ] [21:53:41] Batch 7. Loss (mse): 0.045 <= 0.047 <= 0.049
# [AGT] [INFO    ] [21:55:22] Starting epoch 8
# [AGT] [INFO    ] [21:55:31] Batch 8. Loss (mse): 0.038 <= 0.040 <= 0.043
# [AGT] [INFO    ] [21:57:10] Starting epoch 9
# [AGT] [INFO    ] [21:57:19] Batch 9. Loss (mse): 0.038 <= 0.042 <= 0.047
# [AGT] [INFO    ] [21:58:58] Starting epoch 10
# [AGT] [INFO    ] [21:59:08] Batch 10. Loss (mse): 0.032 <= 0.037 <= 0.042
# [AGT] [INFO    ] [22:00:39] Final Eval. Loss (mse): 0.032 <= 0.038 <= 0.046
# [AGT] [INFO    ] [22:00:39] =================== Finished Privacy Certified Training ===================
#  71%|███████▏  | 5/7 [1:16:37<30:54, 927.47s/it][AGT] [INFO    ] [22:00:39] =================== Starting Privacy Certified Training ===================
# [AGT] [INFO    ] [22:00:39] Starting epoch 1
# [AGT] [INFO    ] [22:00:48] Batch 1. Loss (mse): 0.346 <= 0.346 <= 0.346
# [AGT] [ERROR   ] [22:01:06] Violated bound in validate_interval: 7.99e-02 (grad bounds, private fragment (element 0))
# [AGT] [ERROR   ] [22:01:06] Violated bound in validate_interval: 4.60e-02 (grad bounds, private fragment (element 1))
# [AGT] [INFO    ] [22:02:02] Starting epoch 2
# [AGT] [INFO    ] [22:02:11] Batch 2. Loss (mse): 0.684 <= 0.686 <= 0.687
# [AGT] [INFO    ] [22:03:36] Starting epoch 3
# [AGT] [INFO    ] [22:03:46] Batch 3. Loss (mse): 0.231 <= 0.233 <= 0.235
# [AGT] [INFO    ] [22:05:09] Starting epoch 4
# [AGT] [INFO    ] [22:05:18] Batch 4. Loss (mse): 0.081 <= 0.083 <= 0.085
# [AGT] [INFO    ] [22:06:40] Starting epoch 5
# [AGT] [INFO    ] [22:06:49] Batch 5. Loss (mse): 0.038 <= 0.040 <= 0.042
# [AGT] [INFO    ] [22:08:13] Starting epoch 6
# [AGT] [INFO    ] [22:08:21] Batch 6. Loss (mse): 0.034 <= 0.038 <= 0.041
# [AGT] [INFO    ] [22:09:46] Starting epoch 7
# [AGT] [INFO    ] [22:09:55] Batch 7. Loss (mse): 0.041 <= 0.047 <= 0.053
# [AGT] [INFO    ] [22:11:16] Starting epoch 8
# [AGT] [INFO    ] [22:11:25] Batch 8. Loss (mse): 0.034 <= 0.040 <= 0.048
# [AGT] [INFO    ] [22:12:43] Starting epoch 9
# [AGT] [INFO    ] [22:12:52] Batch 9. Loss (mse): 0.033 <= 0.042 <= 0.054
# [AGT] [INFO    ] [22:14:09] Starting epoch 10
# [AGT] [INFO    ] [22:14:18] Batch 10. Loss (mse): 0.025 <= 0.037 <= 0.051
# [AGT] [INFO    ] [22:15:36] Final Eval. Loss (mse): 0.024 <= 0.038 <= 0.058
# [AGT] [INFO    ] [22:15:36] =================== Finished Privacy Certified Training ===================
#  86%|████████▌ | 6/7 [1:31:34<15:17, 917.17s/it][AGT] [INFO    ] [22:15:36] =================== Starting Privacy Certified Training ===================
# [AGT] [INFO    ] [22:15:36] Starting epoch 1
# [AGT] [INFO    ] [22:15:45] Batch 1. Loss (mse): 0.346 <= 0.346 <= 0.346
# [AGT] [ERROR   ] [22:16:03] Violated bound in validate_interval: 7.99e-02 (grad bounds, private fragment (element 0))
# [AGT] [ERROR   ] [22:16:03] Violated bound in validate_interval: 4.60e-02 (grad bounds, private fragment (element 1))
# [AGT] [INFO    ] [22:17:02] Starting epoch 2
# [AGT] [INFO    ] [22:17:11] Batch 2. Loss (mse): 0.682 <= 0.686 <= 0.689
# [AGT] [INFO    ] [22:18:27] Starting epoch 3
# [AGT] [INFO    ] [22:18:36] Batch 3. Loss (mse): 0.229 <= 0.233 <= 0.237
# [AGT] [INFO    ] [22:19:54] Starting epoch 4
# [AGT] [INFO    ] [22:20:03] Batch 4. Loss (mse): 0.079 <= 0.083 <= 0.087
# [AGT] [INFO    ] [22:21:19] Starting epoch 5
# [AGT] [INFO    ] [22:21:28] Batch 5. Loss (mse): 0.036 <= 0.040 <= 0.045
# [AGT] [INFO    ] [22:22:46] Starting epoch 6
# [AGT] [INFO    ] [22:22:55] Batch 6. Loss (mse): 0.031 <= 0.038 <= 0.045
# [AGT] [INFO    ] [22:24:10] Starting epoch 7
# [AGT] [INFO    ] [22:24:19] Batch 7. Loss (mse): 0.037 <= 0.047 <= 0.059
# [AGT] [INFO    ] [22:25:34] Starting epoch 8
# [AGT] [INFO    ] [22:25:43] Batch 8. Loss (mse): 0.028 <= 0.040 <= 0.057
# [AGT] [INFO    ] [22:27:00] Starting epoch 9
# [AGT] [INFO    ] [22:27:09] Batch 9. Loss (mse): 0.025 <= 0.042 <= 0.067
# [AGT] [INFO    ] [22:28:30] Starting epoch 10
# [AGT] [INFO    ] [22:28:39] Batch 10. Loss (mse): 0.017 <= 0.037 <= 0.070
# [AGT] [INFO    ] [22:30:12] Final Eval. Loss (mse): 0.014 <= 0.038 <= 0.085
# [AGT] [INFO    ] [22:30:12] =================== Finished Privacy Certified Training ===================
# 100%|██████████| 7/7 [1:46:10<00:00, 910.07s/it]

# %%
import torch.nn.functional as F
from abstract_gradient_training.bounded_models import BoundedModel
def noisy_test_mse(
    model: torch.nn.Sequential | BoundedModel,
    batch: torch.Tensor,
    labels: torch.Tensor,
    *,
    noise_level: float | torch.Tensor = 0.0,
    noise_type: str = "laplace",
) -> float:
    """
    Given a pytorch (or bounded) model, calculate the prediction accuracy on a batch of the test set when adding the
    specified noise to the predictions.
    NOTE: For now, this function only supports binary classification via the noise + threshold dp mechanism. This
          should be extended to support multi-class problems via the noisy-argmax mechanism in the future.

    Args:
        model (torch.nn.Sequential | BoundedModel): The model to evaluate.
        batch (torch.Tensor): Input batch of data (shape [batchsize, ...]).
        labels (torch.Tensor): Targets for the input batch (shape [batchsize, ]).
        noise_level (float | torch.Tensor, optional): Noise level for privacy-preserving predictions using the laplace
            mechanism. Can either be a float or a torch.Tensor of shape (batchsize, ).
        noise_type (str, optional): Type of noise to add to the predictions, one of ["laplace", "cauchy"].

    Returns:
        float: The noisy accuracy of the model on the test set.
    """
    # get the test batch and send it to the correct device
    if isinstance(model, BoundedModel):
        device = torch.device(model.device) if model.device != -1 else torch.device("cpu")
    else:
        device = torch.device(next(model.parameters()).device)
    batch = batch.to(device)

    # validate the labels
    if labels.dim() > 1:
        labels = labels.squeeze()
    labels = labels.to(device).type(torch.int64)
    assert labels.dim() == 1, "Labels must be of shape (batchsize, )"

    # validate the noise parameters and set up the distribution
    assert noise_type in ["laplace", "cauchy"], f"Noise type must be one of ['laplace', 'cauchy'], got {noise_type}"
    noise_level += 1e-7  # can't set distributions scale to zero
    noise_level = torch.tensor(noise_level) if isinstance(noise_level, float) else noise_level
    noise_level = noise_level.to(device).type(batch.dtype)  # type: ignore
    noise_level = noise_level.expand(labels.size())
    if noise_type == "laplace":
        noise_distribution = torch.distributions.Laplace(0, noise_level)
    else:
        noise_distribution = torch.distributions.Cauchy(0, noise_level)

    # # nominal, lower and upper bounds for the forward pass
    # logit_n = model.forward(batch).squeeze()

    # # transform 2-logit models to a single output
    # if logit_n.shape[-1] == 2:
    #     logit_n = logit_n[:, 1] - logit_n[:, 0]
    # if logit_n.dim() > 1:
    #     raise NotImplementedError("Noisy accuracy is not supported for multi-class classification.")

    # nominal, lower and upper bounds for the forward pass
    y_n = model.forward(batch).squeeze()

    # transform 2-logit models to a single output
    if y_n.shape[-1] == 2:
        y_n = y_n[:, 1] - y_n[:, 0]
    if y_n.dim() > 1:
        raise NotImplementedError("Noisy accuracy is not supported for multi-class classification.")

    # # apply noise + threshold dp mechanisim
    # y_n = (logit_n > 0).to(torch.float32).squeeze()
    # noise = noise_distribution.sample().to(y_n.device).squeeze()
    # assert noise.shape == y_n.shape
    # y_n = (y_n + noise) > 0.5
    # accuracy = (y_n == labels).float().mean().item()

    # apply noise + threshold dp mechanisim
    noise = noise_distribution.sample().to(y_n.device).squeeze()
    assert noise.shape == y_n.shape
    y_n = y_n + noise
    accuracy = F.mse_loss(y_n, labels.squeeze()).item()
    return accuracy

# %%
for k in k_private_values:
    privacy_bounded_models[k].save_params(f"models/18epochs/uci_k{k}.model")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 2
#       1 for k in k_private_values:
# ----> 2     privacy_bounded_models[k].save_params(f"models/18epochs/uci_k{k}.model")
#
# File /vol/bitbucket/pt321/.venv/lib/python3.10/site-packages/abstract_gradient_training/bounded_models/base_model.py:254, in BoundedModel.save_params(self, filename)
#     247 def save_params(self, filename: str) -> None:
#     248     """
#     249     Save the model parameters to a pytorch file.
#     250
#     251     Args:
#     252         filename (str): Path to the file where the parameters should be saved.
#     253     """
# --> 254     torch.save(
#     255         {
#     256             "param_n": self._param_n,
#     257             "param_l": self._param_l,
#     258             "param_u": self._param_u,
#     259         },
#     260         filename,
#     261     )
#
# File /vol/bitbucket/pt321/.venv/lib/python3.10/site-packages/torch/serialization.py:943, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     940 _check_save_filelike(f)
#     942 if _use_new_zipfile_serialization:
# --> 943     with _open_zipfile_writer(f) as opened_zipfile:
#     944         _save(
#     945             obj,
#     946             opened_zipfile,
#    (...)
#     949             _disable_byteorder_record,
#     950         )
#     951         return
#
# File /vol/bitbucket/pt321/.venv/lib/python3.10/site-packages/torch/serialization.py:810, in _open_zipfile_writer(name_or_buffer)
#     808 else:
#     809     container = _open_zipfile_writer_buffer
# --> 810 return container(name_or_buffer)
#
# File /vol/bitbucket/pt321/.venv/lib/python3.10/site-packages/torch/serialization.py:781, in _open_zipfile_writer_file.__init__(self, name)
#     777     super().__init__(
#     778         torch._C.PyTorchFileWriter(self.file_stream, _compute_crc32)
#     779     )
#     780 else:
# --> 781     super().__init__(torch._C.PyTorchFileWriter(self.name, _compute_crc32))
#
# RuntimeError: Parent directory models/18epochs does not exist.

# %%
import importlib
import privacy_utils_regression
importlib.reload(privacy_utils_regression)

epsilon = 1.0
# make privacy-safe predictions using the smooth sensitivity bounds from AGT
noise_level = privacy_utils_regression.get_calibrated_noise_level(
    test_data.tensors[0], privacy_bounded_models, min_bound=0, max_bound=10000, epsilon=epsilon, noise_type="cauchy" 
)
print(noise_level)
accuracy = noisy_test_mse(
    bounded_model, *test_data.tensors, noise_level=noise_level, noise_type="cauchy"
)
print(accuracy / len(test_data))
print(f"Accuracy using AGT smooth sensitivity bounds: {accuracy:.2f}")

ave = 0
num = 10000
for i in range(num):
    ave += noisy_test_mse(
        bounded_model, *test_data.tensors, noise_level=noise_level, noise_type="cauchy"
    )
print(f"Average MSE is {ave / (num * len(test_data))}")
# Out:
# tensor([0.2549, 0.2549, 0.2549,  ..., 0.2549, 0.2549, 0.2549], device='cuda:0')
# 1.588772794591271
# Accuracy using AGT smooth sensitivity bounds: 325584.03
# Average MSE is 190.5872059983658
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
